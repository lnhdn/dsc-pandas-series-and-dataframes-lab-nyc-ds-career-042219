# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
df_columns = [col.lower() for col in df.columns]


df.columns = [col.upper() for col in df.columns]
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
#Your code here
df = df.set_index('LINENAME')
df.head()
# Out:
#           INDEX   C/A  UNIT       SCP STATION DIVISION       DATE      TIME  \
# LINENAME
# NQR456W       0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# NQR456W       1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# NQR456W       2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# NQR456W       3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# NQR456W       4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#              DESC  ENTRIES  \
# LINENAME
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           EXITS                                                                 \
# LINENAME
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# ...

# %% [markdown]
# ## Painstakingly change the index back

# %%
# Your code here
df = df.reset_index()
df.head()
# Out:
#   LINENAME  INDEX   C/A  UNIT       SCP STATION DIVISION       DATE      TIME  \
# 0  NQR456W      0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W      1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W      2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W      3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W      4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
# ...

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
# Your code here
df['Num_Lines'] = df.LINENAME.map(lambda x: len(x)) #this means create new column name Num_Lines in which u
#call LINENAME and then map to lambda it when x is the linename and len is how many lines.
df.head()
# Out:
#   LINENAME  INDEX   C/A  UNIT       SCP STATION DIVISION       DATE      TIME  \
# 0  NQR456W      0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W      1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W      2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W      3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W      4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.strip()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['LINENAME', 'INDEX', 'C/A', 'UNIT', 'SCP', 'STATION', 'DIVISION',
#        'DATE', 'TIME', 'DESC', 'ENTRIES', 'EXITS', 'NUM_LINES', 'DAY_OF_WEEK',
#        'NUM_LINES', 'day_of_week'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df.head()
df.dtypes
# Out:
# C/A                                                                             object
# UNIT                                                                            object
# SCP                                                                             object
# STATION                                                                         object
# LINENAME                                                                        object
# DIVISION                                                                        object
# DATE                                                                    datetime64[ns]
# TIME                                                                            object
# DESC                                                                            object
# ENTRIES                                                                          int64
# EXITS                                                                            int64
# ...

# %%
#Your code here
df.DATE = pd.to_datetime(df.DATE)
df['day_of_week'] = df.DATE.dt.dayofweek

# %%
grouped= df.groupby('day_of_week').sum()
grouped
# Out:
#                    ENTRIES  \
# day_of_week
# 0            1114237052454
# 1            1143313287046
# 2            1123655222441
# 3            1122723988662
# 4            1110224700078
# 5            1115661545514
# 6            1192306179082
#
#              EXITS
# day_of_week
# 0                                                 911938153513
# 1                                                 942230721477
# 2                                                 920630864687
# 3                                                 920691927110
# 4                                                 906799065337
# 5                                                 909142081474
# 6                                                 959223750461

# %%
#df.groupby('day_of_week').LINENAME.value_counts()

# %%
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
#Your code here
grouped['ENTRIES'].plot(kind='barh')

# %%
grouped['EXITS'].plot(kind='barh')
# Out:
# KeyErrorTraceback (most recent call last)
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EXITS'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-73-4db5f901fef0> in <module>()
# ----> 1 grouped['EXITS'].plot(kind='barh')
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here
df = df.drop('DIVISION', axis =1 )
df.head()
# Out:
#         SCP STATION LINENAME        DATE      TIME     DESC  ENTRIES  \
# 0  02-00-00   59 ST  NQR456W  08/25/2018  00:00:00  REGULAR  6736067
# 1  02-00-00   59 ST  NQR456W  08/25/2018  04:00:00  REGULAR  6736087
# 2  02-00-00   59 ST  NQR456W  08/25/2018  08:00:00  REGULAR  6736105
# 3  02-00-00   59 ST  NQR456W  08/25/2018  12:00:00  REGULAR  6736180
# 4  02-00-00   59 ST  NQR456W  08/25/2018  16:00:00  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
